# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/168time_time__169time_sleep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#168
from time import time
print(f'1979-01-01 00:00:00 이후 지금 현재까지 경과된 초: {time()}')
# Out:
# 1979-01-01 00:00:00 이후 지금 현재까지 경과된 초: 1766235037.3368704

# %%
def cumalatieSum(n):
  ret=0
  for i in range(1,n+1):
    ret+=i
  return ret

# %%
from time import time
n=10000000
stime=time()
answer=cumalativeSum(n)
etime=time()
print(f'1에서 {n:,}까지 누적합 계산 시간: {(etime-stime):.3f}초')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2587316569.py in <cell line: 0>()
#       2 n=10000000
#       3 stime=time()
# ----> 4 answer=cumalativeSum(n)
#       5 etime=time()
#       6 print(f'1에서 {n:,}까지 누적합 계산 시간: {(etime-stime):.3f}초')
#
# NameError: name 'cumalativeSum' is not defined

# %%
#169
from time import sleep
for i in range(1,6):
  print('*'*i)
  sleep(0.5)
# Out:
# *
# **
# ***
# ****
# *****
