# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/142assert_143raise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#142
data=['a','bc',1234,'def','ghij']
try:
  for d in data:
    assert type(d) is str, f'문자열이 아닌 데이터 <{d}> 있음!'
    print(d)
except AssertionError as e:
  print(e)
# Out:
# a
# bc
# 문자열이 아닌 데이터 <1234> 있음!

# %%
#143
def makeException():
  raise RuntimeError('뭔가 잘못되었음')

# %%
try:
  makeException()
except Exception as e:
  print(e)
# Out:
# 뭔가 잘못되었음

# %%
try:
  makeException()
except Exception as e:
  print(e)
  raise
# Out:
# 뭔가 잘못되었음
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2653565888.py in <cell line: 0>()
#       1 try:
# ----> 2   makeException()
#       3 except Exception as e:
#       4   print(e)
#       5   raise
#
# /tmp/ipython-input-3726953982.py in makeException()
#       1 #143
#       2 def makeException():
# ----> 3   raise RuntimeError('뭔가 잘못되었음')
#
# RuntimeError: 뭔가 잘못되었음

# %%
try:
  makeException()
except Exception as e:
  raise ValueError('값이 잘못된 것 같음')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-189609904.py in <cell line: 0>()
#       1 try:
# ----> 2   makeException()
#       3 except Exception as e:
#
# /tmp/ipython-input-3726953982.py in makeException()
#       2 def makeException():
# ----> 3   raise RuntimeError('뭔가 잘못되었음')
#
# RuntimeError: 뭔가 잘못되었음
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-189609904.py in <cell line: 0>()
#       2   makeException()
#       3 except Exception as e:
# ----> 4   raise ValueError('값이 잘못된 것 같음')
#
# ValueError: 값이 잘못된 것 같음
