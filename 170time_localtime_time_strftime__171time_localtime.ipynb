# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/170time_localtime_time_strftime__171time_localtime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#170
from time import localtime,strftime
time_stamp=strftime('%Y-%m-%d %X',localtime())
print(f'현재시간:{time_stamp}')
# Out:
# 현재시간:2025-12-20 12:57:23

# %%
#171
from time import localtime, strftime
t=localtime()
today=strftime('%Y-%m-%d',t)
print(f'{today}은 {t.tm_year}-01-01 이후 {t.tm_yday}일째 되는 날입니다.')
# Out:
# 2025-12-20은 2025-01-01 이후 354일째 되는 날입니다.
