# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/195web_196server.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#195
from fastapi import FastAPI, Request
from fastapi.responses import StreamingResponse
import uvicorn

app=FastAPI()

@app.get("/earthquake")
async def earthquake(request:Request,minmag:float=3.):
    await drawMap(minmag)
    def iterfile():
        with open('earthquake.jpg','rb') as f:
             yield from f

    return StreamingResponse(iterfile()kmedia_type="image/jpeg")
# Out:
#   File "/tmp/ipython-input-3754264638.py", line 15
#     return StreamingResponse(iterfile()kmedia_type="image/jpeg")
#                              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#196
