# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/184multiprocessing_185concurrent_futures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#184
from multiprocessing import process
from time import time

x=2305843009213693951
n=1234567890

p1=Process(target=checkPrimeNumber,args=(x,))
p2=Process(target=cumulativeSum, args=(n,))
stime=time()
p1.start()
p2.start()
p1.join()
p2.join()
etime=time()
print(f'+++총 소요 시간{etime-stime:.2f}초')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2926400900.py in <cell line: 0>()
#       6 n=1234567890
#       7
# ----> 8 p1=Process(target=checkPrimeNumber,args=(x,))
#       9 p2=Process(target=cumulativeSum, args=(n,))
#      10 stime=time()
#
# NameError: name 'Process' is not defined

# %%
#185
from concurrent.futures import ThreadPoolExecutor, as_completed
from time import time

x=2305843009213693951
n=1234567890
threads=[]

stime=time()
executor=ThreadPoolExecutor(max_workers=2)
threads.append(executor.submit(checkPrimeNumber, x))
threads.append(executor.submit(cumulativeSum,n))

for t in as_completed(threads):
  pass

etime=time()
print(f'+++ 총 소요 시간 {etime-stime:.2f}초')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-399255096.py in <cell line: 0>()
#       9 stime=time()
#      10 executor=ThreadPoolExecutor(max_workers=2)
# ---> 11 threads.append(executor.submit(checkPrimeNumber, x))
#      12 threads.append(executor.submit(cumulativeSum,n))
#      13
#
# NameError: name 'checkPrimeNumber' is not defined

# %%
with ThreadPoolExecutor(max_workers=5) as executor:
  fs={executor.submit(loadUrl,url,60): url for url in urls}
  for future in as_completed(fs):
    url=fs[future]
    try:
        data=future.result()
    except Exception as e:
      print(f'{url} 예외 발생: {e}')
    else:
      print(f'{url} 접속 성공: {len(data)} 바이트 수신')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1760447339.py in <cell line: 0>()
#       1 with ThreadPoolExecutor(max_workers=5) as executor:
# ----> 2   fs={executor.submit(loadUrl,url,60): url for url in urls}
#       3   for future in as_completed(fs):
#       4     url=fs[future]
#       5     try:
#
# NameError: name 'urls' is not defined

# %%
stime=time()
with ProcessPoolExecutor() as executor:
  fs = [executor.submit(checkPrimeNumber, target) for target in targets]
  for future in as_completed(fs):
    pass
etime = time()
print(f'+++ 총 소요 시간 {etime-stime:.2f}초')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3344719133.py in <cell line: 0>()
#       1 stime=time()
# ----> 2 with ProcessPoolExecutor() as executor:
#       3   fs = [executor.submit(checkPrimeNumber, target) for target in targets]
#       4   for future in as_completed(fs):
#       5     pass
#
# NameError: name 'ProcessPoolExecutor' is not defined
