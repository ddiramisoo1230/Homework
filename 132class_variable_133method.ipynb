# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/132class_variable_133method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#132
class Wizard:
  generated=0
  def__init__(self,name):
    Wizard.generated+=1
    self.name=name
    self.level=1
    self.hp=100
    self.initAbility()
  def initAbility(self):
    self.strength=1
    self.offense_power=1
    self.intelligence=10
    self.mentality=10
    self.agility=1
# Out:
#   File "/tmp/ipython-input-1695773578.py", line 4
#     def__init__(self,name):
#                           ^
# SyntaxError: invalid syntax

# %%
player1=Wizard('FirePlayer')
print(f'마법사생성 수:{player1.generated}/n캐릭터이름:{player1.name}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3116536505.py in <cell line: 0>()
# ----> 1 player1=Wizard('FirePlayer')
#       2 print(f'마법사생성 수:{player1.generated}/n캐릭터이름:{player1.name}')
#
# NameError: name 'Wizard' is not defined

# %%
player2=Wizard('GodGo')
print(f'마법사생성 수:{palyer2.genterated}/n캐릭터이름:{player2.name}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2902356939.py in <cell line: 0>()
# ----> 1 player2=Wizard('GodGo')
#       2 print(f'마법사생성 수:{palyer2.genterated}/n캐릭터이름:{player2.name}')
#
# NameError: name 'Wizard' is not defined

# %%
player1.level=2
print(f'player1.level={player1.level},player2.level={player2.level}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2789553034.py in <cell line: 0>()
# ----> 1 player1.level=2
#       2 print(f'player1.level={player1.level},player2.level={player2.level}')
#
# NameError: name 'player1' is not defined

# %%
player3=Wizard('StormBaby')
print(player1.generated)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-309135872.py in <cell line: 0>()
# ----> 1 player3=Wizard('StormBaby')
#       2 print(player1.generated)
#
# NameError: name 'Wizard' is not defined

# %%
#133
class Wizard:
  generated=0
  def setFireballLevel(self,power=1):
    self.fireballLevel=power
    print(f'화염구 강도를 {power}로 설정합니다.')
  @classmethod
  def addGenerated(cls,count):
    cls.generated+=count
    print(f'생성된 총 캐릭터 수:{cls.generated}')
  @staticmethod
  def static1():
    print('Wizard 클래스에서 정의된 정적 메서드입니다.')

# %%
player1=Wizard()
player1.setFireballLevel(8)
Wizard.addGenerated(2)
Wizard.static1()
# Out:
# 화염구 강도를 8로 설정합니다.
# 생성된 총 캐릭터 수:2
# Wizard 클래스에서 정의된 정적 메서드입니다.
