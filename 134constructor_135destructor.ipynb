# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/134constructor_135destructor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#134
class Wizard:
  def__init__(self):
    print('마법사 캐릭터가 생성되었습니다.')
# Out:
#   File "/tmp/ipython-input-3536595197.py", line 3
#     def__init__(self):
#                      ^
# SyntaxError: invalid syntax

# %%
player1=Wizard()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-929645639.py in <cell line: 0>()
# ----> 1 player1=Wizard()
#
# NameError: name 'Wizard' is not defined

# %%
class Wizard:
  def__init__(self,name=None):
    self.name=name
    print(f'마법사 이름이 <{self.name}>인 캐릭터가 생성되었습니다.')
# Out:
#   File "/tmp/ipython-input-148742347.py", line 2
#     def__init__(self,name=None):
#                                ^
# SyntaxError: invalid syntax

# %%
#135
class Wizard:
  def __init__(self,name=None):
    self.name=name
    print(f'마법사 이름이 <{name}>인 캐릭터가 생성되었습니다.')
  def __del__(self):
    print('Wizard 객체가 메모리에서 제거됩니다.')

# %%
player1=Wizard('StormBaby')
del player1
# Out:
# 마법사 이름이 <StormBaby>인 캐릭터가 생성되었습니다.
# Wizard 객체가 메모리에서 제거됩니다.
