# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/118d_values__119reversed_d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#118
greats={'유비':89,'관우':95,'장비':91,'조운':94}
levels=greats.values()
print(list(levels))
# Out:
# [89, 95, 91, 94]

# %%
greats['조운']=97
print(list(levels))
# Out:
# [89, 95, 91, 97]

# %%
#119
greats={'유비':89,'관우':95,'장비':91,'조운':94}
levels=reversed(greats)
print(list(levels))
# Out:
# ['조운', '장비', '관우', '유비']
