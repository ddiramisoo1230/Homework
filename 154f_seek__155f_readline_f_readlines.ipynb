# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/154f_seek__155f_readline_f_readlines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#154
with open('prophet_en.txt','r') as f:
  f.seek(335)
  data=f.read()
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-211707984.py in <cell line: 0>()
#       1 #154
# ----> 2 with open('prophet_en.txt','r') as f:
#       3   f.seek(335)
#       4   data=f.read()
#       5 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_en.txt'

# %%
#155
with
open('prophet_en.txt','r') as f:
  line=f.readline()
  while line !='':
    print(f'>>{line[-1]}')
    k=input('다음 줄: 엔터 입력.종류:/q입력:')
    if k=='/q':
      break
    line=f.readline()
# Out:
#   File "/tmp/ipython-input-1199934979.py", line 2
#     with
#          ^
# SyntaxError: invalid syntax

# %%
with open('prophet_en.txt','r') as f:
  lines=f.readline()
  for line in lines:
    print(f'>>{line[:-1]}')
    k=input('다음 줄: 엔터 입력. 종료: /q 입력:')
    if k== '/q':
      break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1589989197.py in <cell line: 0>()
# ----> 1 with open('prophet_en.txt','r') as f:
#       2   lines=f.readline()
#       3   for line in lines:
#       4     print(f'>>{line[:-1]}')
#       5     k=input('다음 줄: 엔터 입력. 종료: /q 입력:')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_en.txt'
