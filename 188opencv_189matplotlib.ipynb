# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/188opencv_189matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#188
import cv2
import numpy as np
from random import shuffle
from math import sqrt

B=[i for i in range(256)]
G=[i for i in range(256)]
R=[i for i in range(256)]

mode=True
is_drawing=False
ix,iy=-1,-1

# %%
def mouseBrush():
  global mode
  img=np.zeros((576,1024,3),np.uint8)
  cv2.nameWindow('drawing pad')
  cv2.setMouseCallback('drawing pad',onMouse,img)

  while True:
    cv2.imshow('drawing pad',img)
    k=cv2.waitKey(1) &0xFF
    if k==27:
      break
    if k == ord('m'):
      mode = not mode

  cv2.destroyAllWindows()
mouseBrush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-318314974.py in <cell line: 0>()
#      14
#      15   cv2.destroyAllWindows()
# ---> 16 mouseBrush()
#
# /tmp/ipython-input-318314974.py in mouseBrush()
#       2   global mode
#       3   img=np.zeros((576,1024,3),np.uint8)
# ----> 4   cv2.nameWindow('drawing pad')
#       5   cv2.setMouseCallback('drawing pad',onMouse,img)
#       6
#
# AttributeError: module 'cv2' has no attribute 'nameWindow'

# %%
#189
import matplotlib
print(matplotlib.matplotlib_fname())
print(matplotlib.get_cachedir())
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/matplotlibrc
# /root/.cache/matplotlib

# %%
import matplotlib.pyplot as plt
import math

# %%
krfont={'family':'NanumGothic','weight':'bold','size':10}
matplotlib.rc('font',**krfont)
matplotlib.rcParams['axes.unicode_minus']=False

# %%
PI=3.141592
xs,ys1,ys2=[],[],[]
for x in range(360):
  xs.append(x)
  ys1.append(math.sin(PI*x/180))
  ys2.append(math.cos(PI*x/180))
