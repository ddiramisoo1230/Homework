# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/199tkinter_200chatgpt_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#199
from tkinter import*
import tkinter.ttk as ttk
import threadingimport socket

HOST='localhost'
PORT=9010
# Out:
#   File "/tmp/ipython-input-150381798.py", line 4
#     import threadingimport socket
#                            ^
# SyntaxError: invalid syntax

# %%
if__name__=='__main__':
  chatgui=chatClient()
  chatgui.run()
# Out:
#   File "/tmp/ipython-input-2409413030.py", line 1
#     if__name__=='__main__':
#                           ^
# SyntaxError: invalid syntax

# %%
#200
import openai
completion=openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
    {"role":"system","content":"넌 무엇이든 쉽게 설명하는 선생님이야"},
    {"role":"user","content":"파이썬 언어에 대해 간략하게 말해줘"}
 ]
)
print(completion.choices[0].message.content)
                                          )
# Out:
#   File "/tmp/ipython-input-1749960977.py", line 11
#     )
#     ^
# IndentationError: unexpected indent
