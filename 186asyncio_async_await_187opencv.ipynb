# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/186asyncio_async_await_187opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#186
import asyncio
from time import time

async def sayAfter(delay,saying):
  print(f'sayAfter({delay}, saying) 시작...')
  await asyncio.sleep(delay)
  print(saying)

# %%
async def main():
  print('비동기 함수 main() 시작...')
  stime=time()
  await sayAfter(1,'안녕하세요!')
  await sayAfter(2,'방가방가~~!')
  etime=time()
  print(f'총 소요시간: {etime-stime:.2f}초')

asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1411566320.py in <cell line: 0>()
#       7   print(f'총 소요시간: {etime-stime:.2f}초')
#       8
# ----> 9 asyncio.run(main())
#
# /usr/lib/python3.12/asyncio/runners.py in run(main, debug, loop_factory)
#     189     if events._get_running_loop() is not None:
#     190         # fail fast with short traceback
# --> 191         raise RuntimeError(
#     192             "asyncio.run() cannot be called from a running event loop")
#     193
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
from time import sleep

async def sayAfter(delay,saying):
  print(f'sayAfter({delay},saying) 시작...')
  sleep(delay)
  print(saying)

# %%
#187
import cv2

def showImage(imgfile):
  img=c2.imread(imgfile,cv2.IMREAD_COLOR)
  cv2.namedWindow('picture',cv2.WINDOW_AUTOSIZE)
  cv2.imshow('picture',img)
  cv2.waitKey(0)
  cv2.destroyAllWindows()

showImage('sunrise.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1549974694.py in <cell line: 0>()
#       9   cv2.destroyAllWindows()
#      10
# ---> 11 showImage('sunrise.jpg')
#
# /tmp/ipython-input-1549974694.py in showImage(imgfile)
#       3
#       4 def showImage(imgfile):
# ----> 5   img=c2.imread(imgfile,cv2.IMREAD_COLOR)
#       6   cv2.namedWindow('picture',cv2.WINDOW_AUTOSIZE)
#       7   cv2.imshow('picture',img)
#
# NameError: name 'c2' is not defined

# %%
def mouseBrush():
  img=np.zeros((576,1024,3),np.uint8)
  cv2.namedWindow('drawing pad')
  cv2.setMouseCallback('drawing pad', onMouse,img)

  while True:
    cv2.imshow('drawing pad',img)
    k=cv2.waitKey(1)&0xFF
    if k==27:
        break
  cv2.destroyAllWindows()

mouseBrush()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-324357276.py in <cell line: 0>()
#      11   cv2.destroyAllWindows()
#      12
# ---> 13 mouseBrush()
#
# /tmp/ipython-input-324357276.py in mouseBrush()
#       1 def mouseBrush():
# ----> 2   img=np.zeros((576,1024,3),np.uint8)
#       3   cv2.namedWindow('drawing pad')
#       4   cv2.setMouseCallback('drawing pad', onMouse,img)
#       5
#
# NameError: name 'np' is not defined
