# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/102set_pop__103set_clear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#102
fruits={'사과','배','오렌지','수박'}
choice=fruits.pop()
print(f'++추출한 요소:{choice}/n++fruits:{fruits}')
# Out:
# ++추출한 요소:사과/n++fruits:{'수박', '오렌지', '배'}

# %%
for _ in range(len(fruits)):
  choise = fruits.pop()
  print(f'++ 추출한 요소: {choice}/n++ fruits: {fruits}')
choise = fruits.pop()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2994870365.py in <cell line: 0>()
#       2   choise = fruits.pop()
#       3   print(f'++ 추출한 요소: {choice}/n++ fruits: {fruits}')
# ----> 4 choise = fruits.pop()
#
# KeyError: 'pop from an empty set'

# %%
#103
set1=set('abradacabra')
set2=set('arirangsong')
set1&=set2
set2.clear()
print(f'set1={set1},set2={set2}')
# Out:
# set1={'r', 'a'},set2=set()
