# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/164shutil_rmtree__165os_path_exists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#164
from shutil import rmtree
folder='c:/mywork/jupyter/myfolder'
k=input(f'<{folder}>를 완전히 삭제하시겠습니까? (y/n):')
if k.lower()=='y':
  rmtree(folder)
  print(f'<{folder}>를 완전히 삭제했습니다.')
else:
  print(f'<{folder}>를 삭제하지 않습니다.')
# Out:
# <c:/mywork/jupyter/myfolder>를 완전히 삭제하시겠습니까? (y/n):y
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3577667614.py in <cell line: 0>()
#       4 k=input(f'<{folder}>를 완전히 삭제하시겠습니까? (y/n):')
#       5 if k.lower()=='y':
# ----> 6   rmtree(folder)
#       7   print(f'<{folder}>를 완전히 삭제했습니다.')
#       8 else:
#
# /usr/lib/python3.12/shutil.py in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     757         try:
#     758             while stack:
# --> 759                 _rmtree_safe_fd(stack, onexc)
#     760         finally:
#     761             # Close any file descriptors still on the stack.
#
# /usr/lib/python3.12/shutil.py in _rmtree_safe_fd(stack, onexc)
#     701     except OSError as err:
#     702         err.filename = path
# --> 703         onexc(func, path, err)
#     704
# ...

# %%
#165
from os.path import exists
print(exists('sunrise.jpg'))
print(exists('tmp'))
print(exists('c:/mywork/jupyter/bts.mp4'))
# Out:
# False
# False
# False

# %%
from os import mkdir
from os.path import exists
while True:
  folder=input('생성할 디렉토리 이름을 입력하세요:')
  if exists(folder):
    print(f'<{folder}>가 이미 존재합니다.')
    continue
  else:
    mkdir(folder)
    print(f'<{folder}>를 생성했습니다.')
    break
# Out:
# 생성할 디렉토리 이름을 입력하세요:tmp
# <tmp>를 생성했습니다.
