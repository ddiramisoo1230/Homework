# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/152f_read__153f_write.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#152
with open('prophet_en.txt','r') as f:
  readData=f.read()
print(readData)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-694711258.py in <cell line: 0>()
#       1 #152
# ----> 2 with open('prophet_en.txt','r') as f:
#       3   readData=f.read()
#       4 print(readData)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_en.txt'

# %%
with open('prophet_ko.txt','r') as f:
  readData=f.read()
print(readData)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1411406651.py in <cell line: 0>()
# ----> 1 with open('prophet_ko.txt','r') as f:
#       2   readData=f.read()
#       3 print(readData)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_ko.txt'

# %%
with open('prophet_cp949_ko.txt','r') as f:
  readData=f.read()
print(readData)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3713395066.py in <cell line: 0>()
# ----> 1 with open('prophet_cp949_ko.txt','r') as f:
#       2   readData=f.read()
#       3 print(readData)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_cp949_ko.txt'

# %%
with open('prophet_cp949_ko.txt','r',encoding='cp949') as f:
# Out:
#   File "/tmp/ipython-input-3670320458.py", line 1
#     with open('prophet_cp949_ko.txt','r',encoding='cp949') as f:
#                                                                 ^
# SyntaxError: incomplete input

# %%
with open('sunrise.jpg','rb') as f:
  readData=f.read(50)
print(readData.hex('-'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-517397826.py in <cell line: 0>()
# ----> 1 with open('sunrise.jpg','rb') as f:
#       2   readData=f.read(50)
#       3 print(readData.hex('-'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sunrise.jpg'

# %%
#153
data=input('저장할 문장을 입력하세요:')
flag=input('입력한 문장을 저장하시겠습니까?(Y/N)')
if flag.lower() == 'y':
  with open('mydata.txt','w') as f:
    f.write(data)
  print('입력한 문장을 "mydata.txt"에 저장했습니다.')
else:
  print('입력한 문장을 저장하지 않습니다.')
# Out:
# 저장할 문장을 입력하세요:ㅇㅇ
# 입력한 문장을 저장하시겠습니까?(Y/N)ㅇ
# 입력한 문장을 저장하지 않습니다.

# %%
data=b'A lot of things occur each day'
with open('mydata.bin','wb') as f:
  f.write(data)

# %%
with open('mydata.bin','rb') as f:
  data=f.read()
print(data)
# Out:
# b'A lot of things occur each day'
