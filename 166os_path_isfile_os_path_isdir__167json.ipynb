# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/166os_path_isfile_os_path_isdir__167json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#166
from os import listdir
from os.path import sdir
fileList=[]
dirList=[]
files=listdir('./')
for file in files:
  if isdir(file):
    dirLst.append(f'<DIR> {file}')
    else:
      fileList.append(file)
fileList.sort()
dirList.sort()
for d i dirList:
  print(d)
for f in fileList:
  print(f)
# Out:
#   File "/tmp/ipython-input-1364709919.py", line 10
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
#167
import json
with open('package.json') as f:
  data=json.load(f)
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3727322889.py in <cell line: 0>()
#       1 #167
#       2 import json
# ----> 3 with open('package.json') as f:
#       4   data=json.load(f)
#       5 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'package.json'

# %%
profile={'name':'조조','age':45,'nationality':'위나라',
         'skill':['집착','배신'],'alive':True}
with open('profile.json''w') as f:
  json.dump(profile,f,indent=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-167581998.py in <cell line: 0>()
#       1 profile={'name':'조조','age':45,'nationality':'위나라',
#       2          'skill':['집착','배신'],'alive':True}
# ----> 3 with open('profile.json''w') as f:
#       4   json.dump(profile,f,indent=4)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'profile.jsonw'

# %%
with open ('pofile.json') as f:
  data=json.load(f)
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2603246461.py in <cell line: 0>()
# ----> 1 with open ('pofile.json') as f:
#       2   data=json.load(f)
#       3 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pofile.json'
