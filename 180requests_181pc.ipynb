# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/180requests_181pc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#180
import requests

def my_urlopen(url):
  header={"User-Agent":"Mozilla/5.0(Windows NT 10.0; Win64; x64)
  Applewebkit/537.36(KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36"}
    try:
      with requests.get(url,headers=header) as r:
          return r
      except Exception as e:
          print(f'my_urlopen() 오류: url={url}/n{e}')
          return None
# Out:
#   File "/tmp/ipython-input-323814785.py", line 5
#     header={"User-Agent":"Mozilla/5.0(Windows NT 10.0; Win64; x64)
#                          ^
# SyntaxError: unterminated string literal (detected at line 5)

# %%
url='https://www.python.org/'
r=my_urlopen(url)
if r!=None:
  doc=r.content.decode()
  with open('pythonhome2.html','w') as h:
    h.write(doc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4057696294.py in <cell line: 0>()
#       1 url='https://www.python.org/'
# ----> 2 r=my_urlopen(url)
#       3 if r!=None:
#       4   doc=r.content.decode()
#       5   with open('pythonhome2.html','w') as h:
#
# NameError: name 'my_urlopen' is not defined

# %%
#181
import requests

def my_urlopen(url):
  header={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari /537.36"}
  try:
      with requests.get(url,headers=header) as r:
        return r
  except Exception as e:
    print(f'my_urlopen() 오류: url={url}/n{e}')
    return None

# %%
def getImgSize(headers):
  try:
    imgsize=int(headers['content-length'])
    return imgsize
  except Exception as e:
      print(f'getImgSize() 오류: {e}')
      return -1

# %%
def saveImage(url,filename):
    r=my_urlopen(url)
    if r!=None:
      imgdata=r.content
      imgsize=getImgSize(r.headers)
      if imgsize ==-1:
        print(f'{url}: 이미지 사이즈를 알 수 없습니다.')
        return
      with open(filename, 'wb') as h:
        h.write(imgdata)
      print(f'이미지 크기: {imgsize:,} 바이트 다운로드 완료')
