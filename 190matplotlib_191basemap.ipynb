# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/190matplotlib_191basemap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#190
import matplotlib.pyplotas plt
import csv
# Out:
#   File "/tmp/ipython-input-2968276421.py", line 2
#     import matplotlib.pyplotas plt
#                                ^
# SyntaxError: invalid syntax

# %%
file='births.txt'
years=range(1800,2012)
pieces=[]
with open(file,'r') as f:
  data=csv.reader(f,delimiter=',')
  for d in data:
    pieces.append(d)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2044134367.py in <cell line: 0>()
#       2 years=range(1800,2012)
#       3 pieces=[]
# ----> 4 with open(file,'r') as f:
#       5   data=csv.reader(f,delimiter=',')
#       6   for d in data:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'births.txt'

# %%
x=[int(year) for year,female,male in pieces]
y1=[int(female) for year, female, male in pieces]
y2=[int(male) for year, female, male in pieces]

plt.plot(x,y1,'r-',labe1='여자아기')
plt.plot(x,y2,'b-',labe1='남자아기')

pit.ylim([0,2500000])
curYticks, _=plt.yticks()
plt.yticks(curYticks,[f'{y:,.0f}'for y in curYticks])

plt.legend()
plt.title('미국 연도별 성별 총 출생아수')
plt.xlable('연도')
plt.ylabel('출생아수')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2268892199.py in <cell line: 0>()
#       3 y2=[int(male) for year, female, male in pieces]
#       4
# ----> 5 plt.plot(x,y1,'r-',labe1='여자아기')
#       6 plt.plot(x,y2,'b-',labe1='남자아기')
#       7
#
# NameError: name 'plt' is not defined
