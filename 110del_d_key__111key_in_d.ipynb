# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/110del_d_key__111key_in_d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#110
names={'Mary':10999,'Cris':2111,'Aimy':9778,'Tom':20245}
del names['Mary']
print(names)
# Out:
# {'Cris': 2111, 'Aimy': 9778, 'Tom': 20245}

# %%
del names['Sams']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3085454307.py in <cell line: 0>()
# ----> 1 del names['Sams']
#
# KeyError: 'Sams'

# %%
#111
names={'Mary':10999,'Cris':2111,'Aimy':9778,'Tom':20245}
name=input('이름을 입력하세요:')
if name in names:
  print(f'이름이<{name}>인 출생아수는 <{names[name]:,d}>명입니다.')
else:
  print(f'딕셔너리 names에 <{name}>인 이름이 존재하지 않습니다.')
# Out:
# 이름을 입력하세요:Cris
# 이름이<Cris>인 출생아수는 <2,111>명입니다.
