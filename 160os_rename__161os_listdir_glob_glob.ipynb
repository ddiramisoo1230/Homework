# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/160os_rename__161os_listdir_glob_glob.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#160
from os import rename
src='sunrise_copied.jpg'
dst='sunrise2.jpg'
rename(src.dst)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4153499911.py in <cell line: 0>()
#       3 src='sunrise_copied.jpg'
#       4 dst='sunrise2.jpg'
# ----> 5 rename(src.dst)
#
# AttributeError: 'str' object has no attribute 'dst'

# %%
src='sunrise2.jpg'
dst='tmp/sunrise2.jpg'
rename(src,dst)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1226244094.py in <cell line: 0>()
#       1 src='sunrise2.jpg'
#       2 dst='tmp/sunrise2.jpg'
# ----> 3 rename(src,dst)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sunrise2.jpg' -> 'tmp/sunrise2.jpg'

# %%
#161
from os import listdir
folder='./'
ret=listdir(folder)
print(ret)
# Out:
# ['.config', 'sample_data']

# %%
from glob import glob
target='*.txt'
ret=glob(target)
print(ret)
# Out:
# []

# %%
target='**'
ret=glob(target,recursive=True)
ret.sort()
for f in ret:
  print(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3692962731.py in <cell line: 0>()
#       1 target='**'
# ----> 2 ret=glob(target,recursive=True)
#       3 ret.sort()
#       4 for f in ret:
#       5   print(r)
#
# NameError: name 'glob' is not defined
