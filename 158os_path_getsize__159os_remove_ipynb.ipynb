# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/158os_path_getsize__159os_remove_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#158
from os.path import getsize
file1='sunrise.jpg'
file2='C:/data/temp/DJI_0128.MP4'
file3='../../temp/DJI_0129.MP4'

# %%
print(f'{file1}: {getsize(file1):,},바이트')
print(f'{file2}: {getsize(file2):,} 바이트')
print(f'{file3}: {getsize(file3):,} 바이트')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2550110100.py in <cell line: 0>()
# ----> 1 print(f'{file1}: {getsize(file1):,},바이트')
#       2 print(f'{file2}: {getsize(file2):,} 바이트')
#       3 print(f'{file3}: {getsize(file3):,} 바이트')
#
# /usr/lib/python3.12/genericpath.py in getsize(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sunrise.jpg'

# %%
#159
from os import remove
target='mydata.txt'
k=input(f'<{target}>을 삭제하시겠습니까? (y/n)')
if k.ower()=='y':
  remove(target)
  print(f'<{target}>을 삭제했습니다.')
else:
  print(f'<{target}>을 삭제하지 않았습니다.')
# Out:
# <mydata.txt>을 삭제하시겠습니까? (y/n)ㅛ
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1473876481.py in <cell line: 0>()
#       3 target='mydata.txt'
#       4 k=input(f'<{target}>을 삭제하시겠습니까? (y/n)')
# ----> 5 if k.ower()=='y':
#       6   remove(target)
#       7   print(f'<{target}>을 삭제했습니다.')
#
# AttributeError: 'str' object has no attribute 'ower'
