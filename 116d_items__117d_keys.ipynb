# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/116d_items__117d_keys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#116
greats={'유비':89,'관우':95,'장비':91,'조운':94}
generals=greats.items()
print(list(generals))
# Out:
# [('유비', 89), ('관우', 95), ('장비', 91), ('조운', 94)]

# %%
del greats['관우']
print(list(generals))
# Out:
# [('유비', 89), ('장비', 91), ('조운', 94)]

# %%
#117
greats={'유비':89,'관우':95,'장비':911,'조운':94}
general_names=greats.keys()
print(list(general_names))

# %%
del greats['관우']
for i, name in enumerate(general_names,start=1):
    print(f'남아 있는 촉나라 장수[{i}]:{name}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2045643127.py in <cell line: 0>()
# ----> 1 del greats['관우']
#       2 for i, name in enumerate(general_names,start=1):
#       3     print(f'남아 있는 촉나라 장수[{i}]:{name}')
#
# KeyError: '관우'
