# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/108d_key_val_109d_setdefault.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#108
nameList=['Mary','Cris','Aimy','Tom','Bob']
population=[10999,2111,9778,20245,27115]
names={}
for k, v in zip(nameList,population):
  names[k]=v
  print(names)
# Out:
# {'Mary': 10999}
# {'Mary': 10999, 'Cris': 2111}
# {'Mary': 10999, 'Cris': 2111, 'Aimy': 9778}
# {'Mary': 10999, 'Cris': 2111, 'Aimy': 9778, 'Tom': 20245}
# {'Mary': 10999, 'Cris': 2111, 'Aimy': 9778, 'Tom': 20245, 'Bob': 27115}

# %%
names['Mary']=20000
print(names)
# Out:
# {'Mary': 20000, 'Cris': 2111, 'Aimy': 9778, 'Tom': 20245, 'Bob': 27115}

# %%
#109
names={'Mary':10999,'Cris':2111,'Aimy':9778}
population=names.setdefault('Sams')
print(f'names:{names}/npopulation:{population}')
# Out:
# names:{'Mary': 10999, 'Cris': 2111, 'Aimy': 9778, 'Sams': None}/npopulation:None

# %%
populaion=names.setdefault('Sams',100)
print(f'names:{names}/npopulaion:{population}')
# Out:
# names:{'Mary': 10999, 'Cris': 2111, 'Aimy': 9778, 'Sams': None}/npopulaion:None

# %%
population=names.setdefault('Tom',1004)
print(f'names: {names}/npopulaion:{population}')
# Out:
# names: {'Mary': 10999, 'Cris': 2111, 'Aimy': 9778, 'Sams': None, 'Tom': 1004}/npopulaion:1004
