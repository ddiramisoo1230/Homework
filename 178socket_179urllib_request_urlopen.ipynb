# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/178socket_179urllib_request_urlopen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#178
import socket
HOST='localhost'
PORT=7777
def echoclient2():
  with socket.socket(socket.AF_INET,socket.SOCK_STREAM) as sock:
    sock.connect((HOST,PORT))

    while True:
      msg=input('메시지 입력:')
      if msg=='/q':
        sock.sendall(msg.encode())
        break
      sock.sendall(msg.encode())
      data=sock.recv(1024)
      print(f'에코 서버로부터 받은 메시지 [{data.decode()}]')

    print('클라이언트 종료')
echoclient2()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /tmp/ipython-input-3990239602.py in <cell line: 0>()
#      17
#      18     print('클라이언트 종료')
# ---> 19 echoclient2()
#
# /tmp/ipython-input-3990239602.py in echoclient2()
#       5 def echoclient2():
#       6   with socket.socket(socket.AF_INET,socket.SOCK_STREAM) as sock:
# ----> 7     sock.connect((HOST,PORT))
#       8
#       9     while True:
#
# ConnectionRefusedError: [Errno 111] Connection refused

# %%
#179
from urllib.request import urlopen
url='https://www.python.org/'
with urlopen(url) as f:
  doc=f.read().decode()
  with open('pythonhome.html','w') as h:
    h.write(doc)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipython-input-1273732114.py in <cell line: 0>()
#       3 url='https://www.python.org/'
#       4 with urlopen(url) as f:
# ----> 5   doc=f.read().decode()
#       6   with open('pythonhome.html','w') as h:
#       7     h.write(doc)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8b in position 1: invalid start byte
