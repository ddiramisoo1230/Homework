# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/150f_open_f_close__151with_open_as_f.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#150

# %%
#151
f=open('myfile.txt','r')
readData=f.readlines()
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2685907008.py in <cell line: 0>()
#       1 #151
# ----> 2 f=open('myfile.txt','r')
#       3 readData=f.readlines()
#       4 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile.txt'

# %%
with open('myfile.txt','r') as f:
  readData=f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3266122629.py in <cell line: 0>()
# ----> 1 with open('myfile.txt','r') as f:
#       2   readData=f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile.txt'
