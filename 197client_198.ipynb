# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/197client_198.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#197
from tkinter importer*
import tkinter.ttk as ttk
from time import time
from threading import Event,Thread
import socket
import json

CHUNK_SIZE=256*1024
# Out:
#   File "/tmp/ipython-input-2696911781.py", line 2
#     from tkinter importer*
#                  ^
# SyntaxError: invalid syntax

# %%
class Downloader():
  def readConfig(self):
    try:
      with open('config.json') as f:
        data=json.load(f)
# Out:
#   File "/tmp/ipython-input-1988091196.py", line 5
#     data=json.load(f)
#                      ^
# SyntaxError: incomplete input

# %%
if__name__=='__main__':
  downloaderGUI=Downloader()
  downloaderGUI.run()
# Out:
#   File "/tmp/ipython-input-3056503704.py", line 1
#     if__name__=='__main__':
#                           ^
# SyntaxError: invalid syntax

# %%
#198
import socketserver
import threading

HOST''
PORT=9010
class UserManager:
  def__init__(self):
    self.users={}
    self.lock=threading.Lock()
# Out:
#   File "/tmp/ipython-input-4142282358.py", line 5
#     HOST''
#         ^
# SyntaxError: invalid syntax
