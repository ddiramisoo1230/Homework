# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/191basemap_192usgs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#191
from mp1_toolkits.basemap import Basemap
import matplotlib.pplot as plt

m=Basemap(projection='mill')
m.drawcoastlines()
m.drawcountries()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2905710732.py in <cell line: 0>()
#       1 #191
# ----> 2 from mp1_toolkits.basemap import Basemap
#       3 import matplotlib.pplot as plt
#       4
#       5 m=Basemap(projection='mill')
#
# ModuleNotFoundError: No module named 'mp1_toolkits'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from mp1_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

m=Basemap(projection='mill')
m.drawcoastlines()
m.drawcountries()
m.bluemarble()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2081687997.py in <cell line: 0>()
# ----> 1 from mp1_toolkits.basemap import Basemap
#       2 import matplotlib.pyplot as plt
#       3
#       4 m=Basemap(projection='mill')
#       5 m.drawcoastlines()
#
# ModuleNotFoundError: No module named 'mp1_toolkits'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#192
def getMarkerColor(mag):
  if mag<4.0:
    return 'bo'
  elif mag<5.0:
    return 'go'
  elif mag<6.0:
    return 'yo'
  elif mag <7.0:
    return 'mo'
  else:
    return 'ro'

# %%
from mp1_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from urllib.request import urlopen
from time import localtime, strftime
from math import sqrt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1262391276.py in <cell line: 0>()
# ----> 1 from mp1_toolkits.basemap import Basemap
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib as mpl
#       4 import numpy as np
#       5 from urllib.request import urlopen
#
# ModuleNotFoundError: No module named 'mp1_toolkits'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
