# %% [markdown]
# <a href="https://colab.research.google.com/github/ddiramisoo1230/Homework/blob/main/144module_145package.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#144
def splitFilename(file):
  buf=filesplit('.')
  if len(buf)>1:
    ext=buf[-1]
    fname='.'.join(buf[:-1])
  else:
    fname=buf[0]
    ext=None
  return (fname,ext)

# %%
import splitfilename
filename='python.200.study.py'
ret=splitfilename.splitFilename(filename)
print(f'파일 이름: {ret[0]}, 파일확장자: {ret[1]}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4165344152.py in <cell line: 0>()
# ----> 1 import splitfilename
#       2 filename='python.200.study.py'
#       3 ret=splitfilename.splitFilename(filename)
#       4 print(f'파일 이름: {ret[0]}, 파일확장자: {ret[1]}')
#
# ModuleNotFoundError: No module named 'splitfilename'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#145
import sound.filters.noraebang
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2596496298.py in <cell line: 0>()
#       1 #145
# ----> 2 import sound.filters.noraebang
#
# ModuleNotFoundError: No module named 'sound'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
